# %% [markdown]
# # Logistic Regression Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the csv file and clead the data
df = pd.read_csv("data/cumulative.csv")
df = df.dropna(axis='columns', how='all')
pd.set_option('display.max_columns', None)
# Drop the null rows
df = df.dropna()
df.head(100)
# Out:
#      rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0        1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1        2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 4        5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# 5        6  10872983  K00756.01  Kepler-228 d       CONFIRMED
# 6        7  10872983  K00756.02  Kepler-228 c       CONFIRMED
# ..     ...       ...        ...           ...             ...
# 145    146   5531576  K00837.01  Kepler-240 c       CONFIRMED
# 146    147   5531576  K00837.02  Kepler-240 b       CONFIRMED
# 148    149   6291653  K00850.01  Kepler-702 b       CONFIRMED
# 149    150   6392727  K00851.01  Kepler-703 b       CONFIRMED
# 150    151   6422070  K00852.01  Kepler-704 b       CONFIRMED
#
#     koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CANDIDATE      1.000              0              0              0
# 1          CANDIDATE      0.969              0              0              0
# 4          CANDIDATE      1.000              0              0              0
# 5          CANDIDATE      1.000              0              0              0
# 6          CANDIDATE      1.000              0              0              0
# ..               ...        ...            ...            ...            ...
# 145        CANDIDATE      1.000              0              0              0
# 146        CANDIDATE      1.000              0              0              0
# 148        CANDIDATE      0.999              0              0              0
# 149        CANDIDATE      1.000              0              0              0
# 150        CANDIDATE      0.876              0              0              0
#
#      koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0                0    9.488036         0.000028        -0.000028   170.538750
# 1                0   54.418383         0.000248        -0.000248   162.513840
# 4                0    2.525592         0.000004        -0.000004   171.595550
# 5                0   11.094321         0.000020        -0.000020   171.201160
# 6                0    4.134435         0.000010        -0.000010   172.979370
# ..             ...         ...              ...              ...          ...
# 145              0    7.953547         0.000019        -0.000019   174.662240
# 146              0    4.144517         0.000014        -0.000014   135.928310
# 148              0   10.526295         0.000002        -0.000002   176.522462
# 149              0    4.583521         0.000004        -0.000004   169.973972
# 150              0    3.761818         0.000011        -0.000011   171.903640
#
#      koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0            0.002160         -0.002160       0.146            0.318
# 1            0.003520         -0.003520       0.586            0.059
# 4            0.001130         -0.001130       0.701            0.235
# 5            0.001410         -0.001410       0.538            0.030
# 6            0.001900         -0.001900       0.762            0.139
# ..                ...               ...         ...              ...
# 145          0.001820         -0.001820       0.300            0.145
# 146          0.003130         -0.003130       0.004            0.471
# 148          0.000136         -0.000136       0.644            0.031
# 149          0.000733         -0.000733       0.045            0.319
# 150          0.002090         -0.002090       0.926            0.000
#
#      koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0             -0.146        2.9575             0.0819            -0.0819
i_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0            -0.096     0.927          0.105         -0.061  291.93423
# 1            -0.096     0.927          0.105         -0.061  291.93423
# 4            -0.210     1.046          0.334         -0.133  288.75488
# 5            -0.229     0.972          0.315         -0.105  296.28613
# 6            -0.229     0.972          0.315         -0.105  296.28613
# ..              ...       ...            ...            ...        ...
# 145          -0.016     0.779          0.023         -0.049  291.15878
# 146          -0.016     0.779          0.023         -0.049  291.15878
# 148          -0.104     0.793          0.143         -0.077  293.87811
# 149          -0.212     0.877          0.260         -0.087  299.18686
# 150          -0.188     0.949          0.260         -0.093  283.31638
#
#            dec  koi_kepmag
# 0    48.141651      15.347
# 1    48.141651      15.347
# 4    48.226200      15.509
# 5    48.224670      15.714
# 6    48.224670      15.714
# ..         ...         ...
# 145  40.750271      15.660
# 146  40.750271      15.660
# 148  41.661770      15.305
# 149  41.742680      15.287
# 150  41.837120      15.257
#
# [100 rows x 48 columns]

# %%
# Drop unnecesary columns 
cleaned_df=df.drop(['rowid','kepid','kepoi_name','kepler_name','koi_pdisposition','koi_period_err1','koi_period_err2',
        'koi_time0bk_err1','koi_time0bk_err2','koi_impact_err1','koi_impact_err2','koi_duration_err1',
       'koi_duration_err2','koi_depth_err1','koi_depth_err2','koi_prad_err1','koi_prad_err2','koi_insol_err1','koi_insol_err2','koi_tce_delivname','koi_steff_err1','koi_steff_err2',
         'koi_slogg_err1','koi_slogg_err2','koi_srad_err1','koi_srad_err2'], axis=1)
cleaned_df
# Out:
#      koi_disposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED      1.000              0              0              0
# 1          CONFIRMED      0.969              0              0              0
# 4          CONFIRMED      1.000              0              0              0
# 5          CONFIRMED      1.000              0              0              0
# 6          CONFIRMED      1.000              0              0              0
# ...              ...        ...            ...            ...            ...
# 9309       CONFIRMED      0.941              0              0              0
# 9353       CONFIRMED      0.877              0              0              0
# 9355       CONFIRMED      0.476              1              0              0
# 9479       CONFIRMED      1.000              0              0              0
# 9540       CONFIRMED      0.911              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0                 0    9.488036    170.53875       0.146        2.9575
# 1                 0   54.418383    162.51384       0.586        4.5070
# 4                 0    2.525592    171.59555       0.701        1.6545
# 5                 0   11.094321    171.20116       0.538        4.5945
# 6                 0    4.134435    172.97937       0.762        3.1402
# ...             ...         ...          ...         ...           ...
# 9309              0   86.116089    134.88080       0.016        6.0580
# 9353              0    0.968981    132.41921       0.065        1.5170
# 9355              0   49.356791    134.29533       0.277       10.9540
# 9479              0   91.078624    213.77230       0.901       10.3040
# 9540              0  386.370512    452.87400       0.010       11.0070
#
#       koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  \
# 0         615.8      2.26    793.0      93.59           35.8
# 1         874.8      2.83    443.0       9.11           25.8
# 4         603.3      2.75   1406.0     926.16           40.9
# 5        1517.5      3.90    835.0     114.81           66.5
# 6         686.0      2.77   1160.0     427.65           40.2
# ...         ...       ...      ...        ...            ...
# 9309      875.2      3.11    441.0       8.93           17.8
# 9353      118.5      1.08   1844.0    2730.51           12.8
# 9355      130.2      1.91    637.0      38.86           35.0
# 9479      738.6      3.26    415.0       7.02           20.8
# 9540     1336.4      2.96    209.0       0.45           13.1
#
#       koi_tce_plnt_num  koi_steff  koi_slogg  koi_srad         ra        dec  \
# 0                  1.0     5455.0      4.467     0.927  291.93423  48.141651
# 1                  2.0     5455.0      4.467     0.927  291.93423  48.141651
# 4                  1.0     6031.0      4.438     1.046  288.75488  48.226200
# 5                  1.0     6046.0      4.486     0.972  296.28613  48.224670
# 6                  2.0     6046.0      4.486     0.972  296.28613  48.224670
# ...                ...        ...        ...       ...        ...        ...
# 9309               1.0     6161.0      4.454     1.053  286.36157  42.963921
# 9353               1.0     5866.0      4.473     1.000  295.34967  45.114552
# 9355               3.0     5862.0      4.050     1.670  289.08606  41.562958
# 9479               1.0     5915.0      4.437     1.008  282.65741  43.162521
# 9540               1.0     5119.0      4.508     0.834  291.39938  38.787750
#
#       koi_kepmag
# 0         15.347
# 1         15.347
# 4         15.509
# 5         15.714
# 6         15.714
# ...          ...
# 9309      15.831
# 9353      15.415
# 9355      11.565
# 9479      15.214
# 9540      15.825
#
# [2269 rows x 22 columns]

# %%
# Assign X (data) and y (target)
X = cleaned_df.drop("koi_disposition", axis=1)
y = cleaned_df["koi_disposition"]

# %%
# Split the train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Build the logistic regression model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
#Fit (train) or model using the training data
classifier.fit(X_train, y_train)
# Out:
# C:\Users\serap\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9947183098591549

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['CONFIRMED' 'CONFIRMED' 'CONFIRMED' 'CONFIRMED' 'CONFIRMED' 'CONFIRMED'
#  'CONFIRMED' 'CONFIRMED' 'CONFIRMED' 'CONFIRMED']
# First 10 Actual labels: ['CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED', 'CONFIRMED']

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                           target_names =["confirmed", "unconfirmed"]))
# Out:
#               precision    recall  f1-score   support
#
#    confirmed       1.00      0.99      1.00       568
#  unconfirmed       0.00      0.00      0.00         0
#
#     accuracy                           0.99       568
#    macro avg       0.50      0.50      0.50       568
# weighted avg       1.00      0.99      1.00       568
# C:\Users\serap\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
